# %% [markdown]
# # Overview

# %%
try:
  # want to attempt this code
  # may have an error

  result = 10 + 10

except: 
  # what to do if there is an error
  print('Hey it looks like something is wrong')

else:
  # what to do if try works
  print('Add went well')
  print(result)
# Out:
# Add went well
# 20

# %%
try:
  # want to attempt this code
  # may have an error

  result = 10 + '10'

except: 
  # what to do if there is an error
  print('Hey it looks like something is wrong')

else:
  # what to do if try works
  print('Add went well')
  print(result)
# Out:
# Hey it looks like something is wrong

# %%
try:
  f = open('testfile', 'w')
  f.write('write a test line')

except TypeError:
  print('There was a type error')
except OSError:
  print('you have an OS error')

finally:
  # finally block always runs no matter what
  print('I always run')
# Out:
# I always run

# %%
try:
  f = open('testfile', 'r') # changed w to r
  f.write('write a test line')

except TypeError:
  print('There was a type error')
except OSError:
  print('you have an OS error')

finally:
  # finally block always runs no matter what
  print('I always run')
# Out:
# you have an OS error
# I always run

# %%
def ask():
  try:
    result = int(input('PLease provide a number: '))
  except:
    print('whoops that is not a number')
  finally:
    print('end of try/except/finally')

# %%
ask()
# Out:
# PLease provide a number: 20
# end of try/except/finally

# %%
ask()
# Out:
# PLease provide a number: word
# whoops that is not a number
# end of try/except/finally

# %%
def ask_for_int():

  while True:
    try:
      result = int(input('Please provide a number: '))

    except:
      print('whoops that is not a number')
      continue
    
    else:
      # if try runs successfully and user inputs a number
      print('yes, thank you')
      break
    
    finally:
      # executes no matter what
      print('end of try/except/finally')

# %%
ask_for_int()
# Out:
# Please provide a number: hello
# whoops that is not a number
# end of try/except/finally
# Please provide a number: working
# whoops that is not a number
# end of try/except/finally
# Please provide a number: 20
# yes, thank you
# end of try/except/finally
