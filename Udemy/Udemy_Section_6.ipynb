# %%
def check_even(number_list):
  # return all even numbers in a list

  even_number = []

  for num in number_list:
    if num % 2 == 0:
      even_number.append(num)
    else:
      pass
  return even_number

# %%
check_even([5,24,858,988415,2,98,5178,1254, 8568, 23894743])
# Out:
# [24, 858, 2, 98, 5178, 1254, 8568]

# %% [markdown]
# # Tuple Unpacking with Python Functions

# %%
stock_prices = [('AAPL', 200), ('GOOG', 1200), ('MSFT', 175), ('AMZN', 2000)]

# %%
for ticker, price in stock_prices:
  print(ticker)
# Out:
# AAPL
# GOOG
# MSFT
# AMZN

# %%
for ticker, price in stock_prices:
  print(price)
# Out:
# 200
# 1200
# 175
# 2000

# %%
stock_prices[0][0]
# Out:
# 'AAPL'

# %%
work_hours = [("abby", 100),('billy', 400), ('cassie', 1000)]

# %%
def employee_check(data):
  current_max = 0
  eom = '' #employee of month based on most hours worked

  for employee, hours in work_hours:
    if hours > current_max:
      current_max = hours
      eom = employee
    else:
      pass

  return (eom, hours)

# %%
employee_check(work_hours)
# Out:
# ('cassie', 1000)

# %%
result = employee_check(work_hours)

# %%
result
# Out:
# ('cassie', 1000)

# %%
name, hours = employee_check(work_hours)

# %%
name
# Out:
# 'cassie'

# %%
hours
# Out:
# 1000

# %% [markdown]
# # Interactions Between Python Functions

# %%
example = [1,2,3,4,5,6,7,]

# %%
from random import shuffle

# %%
shuffle(example)

# %%
example
# Out:
# [4, 1, 2, 3, 6, 5, 7]

# %%
def shuffle_list(lst):
  shuffle(lst)
  return lst

# %%
result = shuffle_list(example)

# %%
result
# Out:
# [5, 3, 4, 6, 1, 7, 2]

# %%
cups = ["", "red ball", ""]

# %%
shuffle_list(cups)
# Out:
# ['red ball', '', '']

# %%
shuffle_list(cups)
# Out:
# ['', '', 'red ball']

# %%
shuffle_list(cups)
# Out:
# ['', '', 'red ball']

# %%
def player_guess():
  # take in player guess for cup game
  guess = " "

  while guess not in ['0', '1', '2']: # input ALWAYS returns a string- make sure guess is either 0,1,2 
    guess = input("Pick a number: 0, 1, or 2- ")

  # input always returns a string so account for that when returning guess

  return int(guess)

# %%
player_guess()
# Out:
# Pick a number: 0, 1, or 2- 0
# 0

# %%
my_index = player_guess()
# Out:
# Pick a number: 0, 1, or 2- 0

# %%
def check_guess(lst, guess):
  if lst[guess] == "red ball":
    print("CORRECT!")
  else:
    print("Wrong guess!")
    print(lst)

# %%
# INITIAL LIST
cups = ['', 'red ball', '']

# SHUFFLE LIST
mixed_up_list = shuffle_list(cups)

# USER GUESS
guess = player_guess()

# CHECK GUESS
check_guess(mixed_up_list, guess)
# Out:
# Pick a number: 0, 1, or 2- 2
# CORRECT!

# %% [markdown]
# #         (COVID-- not Udemy related)

# %%
# pip install covid

# from covid import Covid
# covid = Covid()
# cases = covid.get_status_by_country_name("us")
# for x in cases:
#   print(x,".", cases[x])

# %% [markdown]
# #  **args and **kwargs in Python

# %%
def sum_function(*args):
  # *args returns a tuple
  return sum(args)

# %%
sum_function(40, 60)
# Out:
# 100

# %%
sum_function(40, 60, 100)
# Out:
# 200

# %%
def fav_fruit(**kwargs):
  if 'fruit' in kwargs:
    print(f"My fruit of choice is {(kwargs['fruit'])}")
  else:
    print(" I did not find any fruit I like here")

# %%
fav_fruit(drink ='water', fruit='banana', veggie='lettuce')
# Out:
# My fruit of choice is banana

# %%
def fav_fruit2(**kwargs):
  
  print(kwargs)
  # using print here to show that kwargs returns a dictionary

  if 'fruit' in kwargs:
    print(f"My fruit of choice is {(kwargs['fruit'])}")
  else:
    print(" I did not find any fruit I like here")

# %%
fav_fruit2(fruit='apple', veggie='broccoli')
# Out:
# {'fruit': 'apple', 'veggie': 'broccoli'}
# My fruit of choice is apple

# %%
def myfunc(*args, **kwargs):
  print(args)
  print(kwargs)
  print(f"I would like {args[0]} {kwargs['food']}")

# %%
myfunc(10, 20, 30, fruit='apple', animal='giraffe', food= 'pizzas')
# Out:
# (10, 20, 30)
# {'fruit': 'apple', 'animal': 'giraffe', 'food': 'pizzas'}
# I would like 10 pizzas

# %%
def alternate(text):
  output = ''
  for i in range(0, len(text)):
    if i % 2 == 0:
      output += text[i].upper()
    else:
      output += text[i].lower()
    
  return output

# %%
alternate('anthromorphism')
# Out:
# 'AnThRoMoRpHiSm'

# %% [markdown]
# # **Fucntion Practice Exercises**

# %% [markdown]
# ## Warmup Section
#
# LESSER OF TWO EVENS: Write a function that returns the lesser of two given numbers if both numbers are even, but returns the greater if one or both numbers are odd
#
# lesser_of_two_evens(2,4) --> 2
# lesser_of_two_evens(2,5) --> 5

# %%
def evens(a,b):
  if a%2 == 0 and b%2 == 0:
    return min(a,b)
  else:
    return max(a,b)

# %%
evens(2,4)
# Out:
# 2

# %%
evens(2,5)
# Out:
# 5

# %% [markdown]
# ANIMAL CRACKERS: Write a function takes a two-word string and returns True if both words begin with same letter
# animal_crackers('Levelheaded Llama') --> True
# animal_crackers('Crazy Kangaroo') --> False

# %%
def animal_crackers(some_string):
  s = some_string.split()

  return s[0][0] == s[1][0]

  # if s[0][0] == s[1][0]:
  #   return True
  # else:
  #   return False

# %%
animal_crackers('Levelheaded Llama')
# Out:
# True

# %%
animal_crackers('Crazy Kangaroo')
# Out:
# False

# %%
def animal_crackers(some_string):
  s = some_string.split()

  return s[0][0] == s[1][0]

# %%
animal_crackers('Levelheaded Llama')
# Out:
# True

# %%
animal_crackers("Johnny Thomson")
# Out:
# False

# %% [markdown]
# MAKES TWENTY: Given two integers, return True if the sum of the integers is 20 or if one of the integers is 20. If not, return False¶
# makes_twenty(20,10) --> True
# makes_twenty(12,8) --> True
# makes_twenty(2,3) --> Fals

# %%
def makes20(a, b):
  return a == 20 or b == 20 or a+b == 20

# %%
makes20(20,10)
# Out:
# True

# %%
makes20(2,3)
# Out:
# False

# %% [markdown]
# ## LEVEL 1 PROBLEMS

# %% [markdown]
# OLD MACDONALD: Write a function that capitalizes the first and fourth letters of a name
#
#
# old_macdonald('macdonald') --> MacDonald

# %%
def old_macdonald(name):
  name = name[0].upper() + name[1:3] + name[3].upper() + name[4:]
  return name

# %%
old_macdonald('macdonald')
# Out:
# 'MacDonald'

# %%
old_macdonald('popeye')
# Out:
# 'PopEye'

# %% [markdown]
# MASTER YODA: Given a sentence, return a sentence with the words reversed
#
# master_yoda('I am home') --> 'home am I'
# master_yoda('We are ready') --> 'ready are We'

# %%
def master_yoda(text):
  text = text.split()

  return " ".join(text[::-1])

# %%
master_yoda('I am home')
# Out:
# 'home am I'

# %%
master_yoda('We are ready')
# Out:
# 'ready are We'

# %% [markdown]
# ALMOST THERE: Given an integer n, return True if n is within 10 of either 100 or 200
#
#
# almost_there(90) --> True
#
# almost_there(104) --> True
#
# almost_there(150) --> False
#
# almost_there(209) --> True

# %%
def almost_there(n):
  # return 89 < n < 111 or 189 < n < 211

  return (abs(100-n) <= 10) or (abs(200-n) <= 10)

# %%
almost_there(90)
# Out:
# True

# %%
almost_there(104)
# Out:
# True

# %%
almost_there(150)
# Out:
# False

# %%
almost_there(209)
# Out:
# True

# %% [markdown]
# ## LEVEL 2 PROBLEMS

# %% [markdown]
# FIND 33
# Given a list of ints, return True if the array contains a 3 next to a 3 somewhere.
#
# has_33([1, 3, 3]) → True
#
# has_33([1, 3, 1, 3]) → False
#
# has_33([3, 1, 3]) → False

# %%
def has_33(nums, k):
  
  consecutive3 = 0

  for i in range(0, len(nums)):
    if nums[i] == 3:

      consecutive3 += 1

      if consecutive3 == k:
        return True
    
    else:
      consecutive3 = 0
    
  return False

# %%
has_33([1, 3, 3], 3)
# Out:
# False

# %%
has_33([1, 3, 1, 3, 3, 3], 3)
# Out:
# True

# %%
has_33([3, 1, 3])
# Out:
# False

# %% [markdown]
# PAPER DOLL: Given a string, return a string where for every character in the original there are three characters
#
# paper_doll('Hello') --> 'HHHeeellllllooo'
#
# paper_doll('Mississippi') --> 'MMMiiissssssiiippppppiii'

# %%
def paper_doll(text):
  new = ''
  for i in text:
    new += i*3

  return new

# %%
paper_doll('Hello')
# Out:
# 'HHHeeellllllooo'

# %%
paper_doll('Mississippi')
# Out:
# 'MMMiiissssssiiissssssiiippppppiii'

# %%
paper_doll('Shashank')
# Out:
# 'SSShhhaaassshhhaaannnkkk'

# %% [markdown]
# BLACKJACK: Given three integers between 1 and 11, if their sum is less than or equal to 21, return their sum. If their sum exceeds 21 and there's an eleven, reduce the total sum by 10. Finally, if the sum (even after adjustment) exceeds 21, return 'BUST'
#
# blackjack(5,6,7) --> 18
#
# blackjack(9,9,9) --> 'BUST'
#
# blackjack(9,9,11) --> 19

# %%
def blackjack(a, b, c):
  if a == 11 or b == 11 or c == 11:
    return sum([a,b,c]) - 10 
  elif sum([a,b,c]) <= 21:
    return sum([a,b,c])
  else:
    return "BUST"

# %%
blackjack(5,6,7)
# Out:
# 18

# %%
blackjack(9,9,9)
# Out:
# 'BUST'

# %%
blackjack(9,9,11)
# Out:
# 19

# %% [markdown]
# SPY GAME: Write a function that takes in a list of integers and returns True if it contains 007 in order
#
#  spy_game([1,2,4,0,0,7,5]) --> True
#
#  spy_game([1,0,2,4,0,5,7]) --> True
#
#  spy_game([1,7,2,0,4,5,0]) --> False

# %%
def spy_game(nums):

  code = [0,0,7, 'x']

  for num in nums:
    if num == code[0]:
      code.pop(0)
  return len(code) == 1

# %%
spy_game([1,2,4,0,0,7,5])
# Out:
# True

# %%
spy_game([1,0,2,4,0,5,7])
# Out:
# True

# %%
spy_game([1,7,2,0,4,5,0])
# Out:
# False

# %% [markdown]
# COUNT PRIMES: Write a function that returns the number of prime numbers that exist up to and including a given number
#
# count_primes(100) --> 25
#
# By convention, 0 and 1 are not prime.

# %%
def count_primes(num):
  primes = [2]
  x = 3
  if num < 2:
      return 0
  while x <= num:
      for y in range(3, x, 2):  
          if x%y == 0:
              x += 2
              break
      else:
          primes.append(x)
          x += 2
  print(primes)
  return len(primes)

# %%
def print_big(letter):
    patterns = {1:'  *  ',2:' * * ',3:'*   *',4:'*****',5:'**** ',6:'   * ',7:' *   ',8:'*   * ',9:'*    '}
    alphabet = {'A':[1,2,4,3,3],'B':[5,3,5,3,5],'C':[4,9,9,9,4],'D':[5,3,3,3,5],'E':[4,9,4,9,4]}
    for pattern in alphabet[letter.upper()]:
        print(patterns[pattern])

# %%
print_big('E')
# Out:
# *****
# *
# *****
# *
# *****

# %% [markdown]
# # Lambda Expressions, Map, and Filter Functions

# %%
def square(num):
  return num**2

# %%
my_nums = [1,2,3,4,5]

# %%
for item in map(square, my_nums):
  print(item)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
list(map(square, my_nums))
# Out:
# [1, 4, 9, 16, 25]

# %%
def splicer(mystring):
  if len(mystring)%2 == 0:
    return 'EVEN'
  else:
    return mystring[0]

# %%
names = ['Adam', 'Eve', "John", "Spongebob"]

# %%
list(map(splicer, names))
# Out:
# ['EVEN', 'E', 'EVEN', 'S']

# %%
def check_even(num):
  return num % 2 == 0

# %%
my_nums = [1,2,3,4,5,6,7,8,9]

# %%
list(filter(check_even, my_nums))
# Out:
# [2, 4, 6, 8]

# %%
for n in filter(check_even, my_nums):
  print(n)
# Out:
# 2
# 4
# 6
# 8

# %%
square(3)
# Out:
# 9

# %%
list(map(lambda num: num ** 3, my_nums))
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729]

# %%
list(filter(lambda num: num%2== 0, my_nums))
# Out:
# [2, 4, 6, 8]

# %%
names
# Out:
# ['Adam', 'Eve', 'John', 'Spongebob']

# %%
list((map(lambda x: x[::-1], names)))
# Out:
# ['madA', 'evE', 'nhoJ', 'bobegnopS']

# %% [markdown]
# # Methods and Functions Homework

# %%
def vol(radius):
  return ((4/3) * 3.14159 * radius**3)

# %%
vol(2)
# Out:
# 33.51029333333333

# %%
# Write a function that checks whether a number is in a given range (inclusive of high and low)

# %%
def run_check(num, low, high):
  return num in range(low, high)

# %%
run_check(5,2,7)
# Out:
# True

# %% [markdown]
# Write a Python function that accepts a string and calculates the number of upper case letters and lower case letters.
#
# Sample String : 'Hello Mr. Rogers, how are you this fine Tuesday?'
#
#
# Expected Output :
#
# No. of Upper case characters : 4
#
# No. of Lower case Characters : 33

# %%
def up_low(text):
  up = 0
  low = 0
  for letter in text:
    if letter.isupper() == True:  
        up += 1
    elif letter.islower() == True:
        low += 1
    else:
      pass

  print(f'No. of Upper case characters: {up}')
  print(f'No. of Lower case character: {low}')

# %%
s = 'Hello Mr. Rogers, how are you this fine Tuesday?'

# %%
up_low(s)
# Out:
# No. of Upper case characters: 4
# No. of Lower case character: 33

# %% [markdown]
# Write a Python function that takes a list and returns a new list with unique elements of the first list.
#
# Sample List : [1,1,1,1,2,2,3,3,3,3,4,5]
#
# Unique List : [1, 2, 3, 4, 5]

# %%
def unique_list(lst):
  U_nums = []

  for num in lst:
    if num in U_nums:
      continue
    else:
      U_nums.append(num)
  return U_nums

# %%
Sample_List = [1,1,1,1,2,2,3,3,3,3,4,5]

# %%
unique_list(Sample_List)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Write a Python function to multiply all the numbers in a list.
#
# Sample List : [1, 2, 3, -4]
#
# Expected Output : -24

# %%
 from functools import reduce

# %%
 result1 = reduce(lambda x, y: x*y, lst)

# %%
print(result1)
# Out:
# 120

# %%
def multiply(numbers):  
    total = 1
    for x in numbers:
        total *= x  
    return total

# %%
lst= [1,2,3,4,5]

# %%
multiply(lst)
# Out:
# 120

# %%
def palindrome(text):
  return text == text[::-1]

# %%
palindrome('racecar')
# Out:
# True

# %%
palindrome('Johnny')
# Out:
# False

# %%
import string
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def ispangram(str1, alphabet=string.ascii_lowercase):
