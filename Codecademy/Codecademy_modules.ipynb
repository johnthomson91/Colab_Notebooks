# %%
import random

# Create random_list below:
random_list = [random.randint(1,101) for i in range(101)]

# Create randomer_number below:
randomer_number = random.choice(random_list)

# Print randomer_number below:
print(randomer_number)
# Out:
# 60

# %%
from datetime import datetime

current_time = datetime.now()

print(current_time)
# Out:
# 2020-11-28 02:26:51.640115

# %%
rand_num = random.randint(1,101)
rand_num
# Out:
# 12

# %%
from matplotlib import pyplot as plt

import random

numbers_a = range(1, 13)

numbers_b = random.sample(range(1000), 12)

# %%
plt.plot(numbers_a, numbers_b)

plt.show()

# %%
from decimal import Decimal

# Fix the floating point math below:
two_decimal_points = Decimal('0.2') + Decimal('0.69')
print(two_decimal_points)

four_decimal_points = Decimal('0.53') * Decimal('0.65')
print(four_decimal_points)

# %%
x = round(3.1415926, 2)
print(x)
# Out:
# 3.14

# %%
from datetime import datetime

# %%
birthday =  datetime(1191, 2, 14, 20, 14)

# %%
birthday.year
# Out:
# 1191

# %%
birthday.month
# Out:
# 2

# %%
birthday.hour
# Out:
# 20

# %%
birthday.weekday()
#Thursday
# Out:
# 3

# %%
datetime.now()
# Out:
# datetime.datetime(2020, 11, 28, 2, 54, 8, 472075)

# %%
datetime(2018, 1, 1 ) - datetime(2017, 1, 1)
# Out:
# datetime.timedelta(365)

# %%
datetime.now() - datetime(2020, 1, 1)
#time since start of worst year ever
#(days, seconds, microseconds)
# Out:
# datetime.timedelta(332, 10587, 983359)

# %%
parsed_date = datetime.strptime("Nov 27, 2020", "%b %d, %Y")

# %%
parsed_date
# Out:
# datetime.datetime(2020, 11, 27, 0, 0)

# %%
parsed_date.day
# Out:
# 27

# %%
parsed_date = datetime.strptime("Jul 4, 2011", "%b %d, %Y")

# %%
parsed_date.month
# Out:
# 7

# %%
date_string = datetime.strftime(datetime.now(), '%b %d, %Y')

# %%
date_string
# Out:
# 'Nov 28, 2020'

# %%
# vitrual envrionments

# pipenv
