# %% [markdown]
# # Define a Class

# %% [markdown]
# Think of objects as nouns and their methods as verbs
#
# An object represents an individual thing, and its methods define how it interacts with other things

# %%
 'hello'.upper()
# Out:
# 'HELLO'

# %%
class Person():
  def __init__(self, name):
    self.name = name

# %%
hunter = Person('ELmer Fudd')

# %%
print(f"The mighty hunter: {hunter.name}")
# Out:
# The mighty hunter: ELmer Fudd

# %% [markdown]
# # Inheritance

# %%
class Car():
  def exclaim(self):
    print("I am a car!")

# %%
class Yugo(Car):
  pass

# %%
give_me_a_car = Car()
give_me_a_Yugo= Yugo()

# %%
give_me_a_car.exclaim()
# Out:
# I am a car!

# %%
give_me_a_Yugo.exclaim()
# Out:
# I am a car!

# %% [markdown]
# Yugo inherits Cars properties here and nothing is overwritten so .exclaim() prints out the same thing for both

# %%
class Yugo2(Car):
  def exclaim(self):
    print("I'm a Yugo! Much like a car, but more Yugo-ish")

# %%
give_me_a_Yugo_2 = Yugo2()

# %%
give_me_a_car.exclaim()
# Out:
# I am a car!

# %%
give_me_a_Yugo_2.exclaim()
# Out:
# I'm a Yugo! Much like a car, but more Yugo-ish

# %%
class Person():

  def __init__(self, name):
    self.name = name
    print(self.name)

# %%
class MDPerson(Person):

  def __init__(self, name):
    self.name = f"Doctor {name}"

# %%
class JDPerson(Person):

  def __init__(self,name):
    self.name = name
    print(f"{self.name}, Esquire")

# %%
person = Person('Thomson')
doctor = MDPerson('Thomson')
lawyer = JDPerson('Thomson')
# Out:
# Thomson
# Thomson, Esquire

# %%
print(doctor.name)
# Out:
# Doctor Thomson

# %%
class Yugo2(Car):

  def exclaim(self):
    print("I'm a Yugo! Much like a car, but more Yugo-ish")

  def push(self):
    print("A little help here, please")

# %%
give_me_a_Yugo_2 = Yugo2()

# %%
give_me_a_Yugo_2.exclaim()
# Out:
# I'm a Yugo! Much like a car, but more Yugo-ish

# %%
give_me_a_Yugo_2.push()

# give_me_a_car.push() would obviously not work
# Out:
# A little help here, please

# %%
give_me_a_car.exclaim()
# Out:
# I am a car!

# %% [markdown]
# # Super( )

# %%
class Person():

  def __init__(self, name):
    self.name = name

# %%
class EmailPerson(Person):

  def __init__(self, name, email):
    super().__init__(name)
    self.email = email

# %%
bob = EmailPerson('Bob Frapples', 'bob@frapples.com')

# %%
bob.name
# Out:
# 'Bob Frapples'

# %%
bob.email
# Out:
# 'bob@frapples.com'

# %% [markdown]
# # Decorators

# %%
class Duck():

  def __init__(self, input_name):
    self.hidden_name = input_name

  def get_name(self):
    print('inside the getter')
    return self.hidden_name

  def set_name(self, input_name):
    print('inside the setter')
    self.hidden_name = input_name
  
  name = property(get_name, set_name)

# %%
fowl = Duck('Donald')

# %%
# when you refer to the name of any Duck object, 
# it actually calls the get_name() method to return it

fowl.name
# Out:
# inside the getter
# 'Donald'

# %%
fowl.get_name()
# Out:
# inside the getter
# 'Donald'

# %%
# when you assign a value to the name attribute, the set_name() method will be called

fowl.name = 'Daffy'
# Out:
# inside the setter

# %%
fowl.name
# Out:
# inside the getter
# 'Daffy'

# %%
fowl.set_name('Daffy Duck')
# Out:
# inside the setter

# %%
fowl.name
# Out:
# inside the getter
# 'Daffy Duck'

# %%
class Duck():

  def __init__(self, input_name):
    self.hidden_name = input_name
  
  @property
  def name(self):
    print('inside the getter')
    return self.hidden_name
  
  @name.setter
  def name(self, input_name):
    print('inside the setter')
    self.hidden_name = input_name

# %%
fowl= Duck('Donald Duck')

# %%
fowl.name
# Out:
# inside the getter
# 'Donald Duck'

# %%
fowl.name = 'Oregon Ducks'
# Out:
# inside the setter

# %%
fowl.name
# Out:
# inside the getter
# 'Oregon Ducks'

# %%
class Circle():

  def __init__(self, radius):
    self.radius = radius
  
  @property
  def diameter(self):
    return 2*self.radius

# %%
c= Circle(5)

# %%
c.radius
# Out:
# 5

# %%
c.diameter
# Out:
# 14

# %%
c.radius = 7

# %%
c.diameter
# Out:
# 14

# %% [markdown]
# Name Mangling for Privacy
#
# use __name

# %%
class Duck():

  def __init__(self, input_name):
    self.__name = input_name
  
  @property
  def name(self):
    print('inside the getter')
    return self.__name
  
  @name.setter
  def name(self, input_name):
    print('inside the setter')
    self.__name = input_name

# %%
fowl=Duck('Howard')

# %%
fowl.name
# Out:
# inside the getter
# 'Howard'

# %%
fowl.name = 'Snape'
# Out:
# inside the setter

# %%
fowl.name
# Out:
# inside the getter
# 'Snape'

# %%
# fowl.__name doesnt work

# %%
fowl._Duck__name
# Out:
# 'Snape'

# %%
class A():

  count = 0

  def __init__(self):
    A.count += 1
  
  def exclaim(self):
    print("I'm an A!")

  @classmethod
  def kids(cls):
    print(f"'A' has {cls.count} little objects")

# %%
easy_a = A()
breezy_a = A()

# %%
A.kids()
# Out:
# 'A' has 2 little objects

# %%
wheezy_a = A()

# %%
A.kids()
# Out:
# 'A' has 3 little objects

# %% [markdown]
# notice we referred to A.count (the class attribute) rather than self.count (which would be an object instance attribute.
#
# In the kids() method, we used cls.count, but we could just as well have used A.count

# %%
class CoyoteWeapon():
  @staticmethod
  def commercial():
    print('This CoyoteWeapon has been brought to you by Acme')

# %%
CoyoteWeapon.commercial()
# Out:
# This CoyoteWeapon has been brought to you by Acme

# %% [markdown]
# we didnt need to create an object from class CoyoteWeapon to access this method

# %% [markdown]
# # Polymorphism

# %%
class Quote():
  def __init__(self, person, words):
    self.person = person
    self.words = words

  def who(self):
    return self.person

  def says(self):
    return self.words + '.'

class QuestionQuote(Quote):
  def says(self):
    return self.words + '?'

class ExclamationQuote(Quote):
  def says(self):
    return self.words + '!'

# %%
hunter = Quote('Elmder Fudd', "I'm hunting wabbits")

# %%
print(hunter.who(), 'says: ', hunter.says())
# Out:
# Elmder Fudd says:  I'm hunting wabbits.

# %%
hunted1 = QuestionQuote('Bugs Bunny', "What's up, doc")

# %%
print(hunted1.who(), 'says: ', hunted1.says())

# notice the question mark because we used the QuestionQuote class
# Out:
# Bugs Bunny says:  What's up, doc?

# %%
hunted2 = ExclamationQuote('Daffy Duck', "It's rabbit season")

# %%
print(f"{hunted2.who()} says: {hunted2.says()}")
# Out:
# Daffy Duck says: It's rabbit season!

# %%
class BabblingBrook():
  def who(self):
    return 'Brook'
  def says(self):
    return 'Babble'

# %%
brook = BabblingBrook()

# %%
brook.who()
# Out:
# 'Brook'

# %%
brook.says()
# Out:
# 'Babble'

# %%
def who_says(obj):
  print(f"{obj.who()} says: {obj.says()}")

# %%
who_says(hunter)
# Out:
# Elmder Fudd says: I'm hunting wabbits.

# %%
who_says(hunted1)
# Out:
# Bugs Bunny says: What's up, doc?

# %%
who_says(hunted2)
# Out:
# Daffy Duck says: It's rabbit season!

# %%
who_says(brook)
# Out:
# Brook says: Babble

# %% [markdown]
# # Special Methods

# %%
class Word():
  def __init__(self, text):
    self.text = text
  
  def equals(self,word2):
    return self.text.lower() == word2.text.lower()

# %%
first = Word('ha')
second = Word('HA')
third = Word('hey')

# %%
first.equals(second)
# Out:
# True

# %%
first.equals(third)
# Out:
# False

# %%
second.equals(first)
# Out:
# True

# %%
second.equals(third)
# Out:
# False

# %%
class Word():
  def __init__(self, text):
    self.text = text
  
  def __eq__(self, word2):
    return self.text.lower() == word2.text.lower()

# %%
first = Word('ha')
second = Word('HA')
third = Word('hey')

# %%
first == second
# Out:
# True

# %%
first == third
# Out:
# False

# %%
second == first
# Out:
# True

# %%
second == third
# Out:
# False

# %%
first

# %%
class Word():
  def __init__(self, text):
    self.text = text
  def __eq__(self, word2):
    return self.text.lower() ==  word2.text.lower()
  def __str__(self):
    return self.text
  def __repr__(self):
    return f" lets show how this works -- Word ( '{self.text}' )"

# %%
first = Word('ha')

# %%
first # uses __repr__
# Out:
#  lets show how this works -- Word ( 'ha' )

# %%
print(first) # uses  __str__
# Out:
# ha

# %% [markdown]
# # Aggregation and Composition

# %%
class Bill():
  def __init__(self, description):
    self.description = description

# %%
class Tail():
  def __init__(self, length):
    self.length = length

# %%
class Duck():
  def __init__(self, bill, tail):
    self.bill = bill
    self.tail = tail
  
  def about(self):
    print(f"This duck has a {self.bill.description} bill and a {self.tail.length} tail")

# %%
a_tail = Tail('long')

# %%
a_bill = Bill('wide orange')

# %%
duck = Duck(a_bill, a_tail)

# %%
duck.about()
# Out:
# This duck has a wide orange bill and a long tail

# %% [markdown]
# # Named Tuples

# %%
from collections import namedtuple

# %%
Duck_Tuple = namedtuple('Duck', 'bill tail')

# %%
duck_tup = Duck_Tuple('wide orange', 'long')

# %%
duck_tup
# Out:
# Duck(bill='wide orange', tail='long', name='Donald')

# %%
duck_tup.bill
# Out:
# 'wide orange'

# %%
duck_tup.tail
# Out:
# 'long'

# %%
# you can also make a tuple from a dictionary

# %%
parts = {'bill': 'wide orange', 'tail': 'long'}

# %%
duck2 = Duck_Tuple(**parts)

# %%
duck2
# Out:
# Duck(bill='wide orange', tail='long')

# %%
duck3 = duck2._replace(tail = 'magnificent', bill= 'crushing')

# %%
duck3
# Out:
# Duck(bill='crushing', tail='magnificent')

# %%
duck_dict = {'bill': 'wide orange', 'tail': 'long'}

# %%
duck_dict
# Out:
# {'bill': 'wide orange', 'tail': 'long'}

# %%
duck_dict['color'] = 'green'

# %%
duck_dict
# Out:
# {'bill': 'wide orange', 'color': 'green', 'tail': 'long'}

# %% [markdown]
# # Excercises

# %%
  class Thing():
    letters = 'abc'
    print(letters)
# Out:
# abc

# %%
Thing()

# %%
Thing.letters
# Out:
# 'abc'

# %%
# make a class called Thing3 and assign the value 'xyz'
# to an instance (object) attribute called letters
# print letters

class thing3():
  def __init__(self):
    self.letters = 'xyz'

# %%
something = thing3()

# %%
something.letters
# Out:
# 'xyz'

# %%
class Elements():

  def __init__(self, name, symbol, number):
    self.name = name
    self.symbol = symbol
    self.number = number

# %%
hydrogen = Elements('hydrogen', 'H', 1)

# %%
hydrogen.symbol
# Out:
# 'H'

# %%
gold = Elements('gold', 'au', 79)

# %%
gold.number
# Out:
# 79

# %%
hy_dict = {'name': 'Hydrogen', 'symbol': 'H', 'number': 1}

# %%
hydrogen2 = Elements(**hy_dict)

# %%
hydrogen2.name
# Out:
# 'Hydrogen'

# %%
hydrogen2.number
# Out:
# 1

# %%
class Elements():

  def __init__(self, name, symbol, number):
    self.name = name
    self.symbol = symbol
    self.number = number
  
  def dump(self):
    print(f"{self.name}, '{self.symbol}', {self.number}")

# %%
oxygen = Elements('Oxygen', 'O', 8)

# %%
oxygen.dump()
# Out:
# Oxygen, 'O', 8

# %%
class Elements():

  def __init__(self, name, symbol, number):
    self.name = name
    self.symbol = symbol
    self.number = number 
  
  def __str__(self):
    return (f"Name: {self.name}, Symbol: '{self.symbol}', Number: {self.number}")

# %%
gold = Elements('gold', 'au', 79)

# %%
print(gold)
# Out:
# Name: gold, Symbol: 'au', Number: 79
