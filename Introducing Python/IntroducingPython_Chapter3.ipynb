# %%
pythons= {'Chapman':'Graham', 'Cleese':"John", "Jones":"Terry", "Palin":"Michael"}

# %%
"Chapman" in pythons
# Out:
# True

# %%
"Palin" in pythons
# Out:
# True

# %%
pythons["Cleese"]
# Out:
# 'John'

# %%
pythons.get('Chapman')
# Out:
# 'Graham'

# %%
pythons.get("Marx", "not a Python")
# Out:
# 'not a Python'

# %%
signals = {"green":"go", 'yellow':'go faster', "red":"smile for the camera"}

# %%
signals.keys()
# Out:
# dict_keys(['green', 'yellow', 'red'])

# %%
# in Python 3 .keys() returns a dictionary but you can call list() to convert the dictionary to a list
list(signals.keys())
# Out:
# ['green', 'yellow', 'red']

# %%
# use .values() to obtain all the values in the dictionary
list(signals.values())
# Out:
# ['go', 'go faster', 'smile for the camera']

# %%
# .items() is used to get all the key:value pairs from a dictionary
list(signals.items())
# Out:
# [('green', 'go'), ('yellow', 'go faster'), ('red', 'smile for the camera')]

# %%
signals
# Out:
# {'green': 'go', 'yellow': 'go faster', 'red': 'smile for the camera'}

# %%
save_signals = signals

# %%
signals['blue']= 'confuse everyone'
save_signals
# Out:
# {'green': 'go',
#  'yellow': 'go faster',
#  'red': 'smile for the camera',
#  'blue': 'confuse everyone'}

# %%
signals = {"green":"go", 'yellow':'go faster', "red":"smile for the camera"}

# %%
original_signals = signals.copy()

# %%
signals['blue']= 'confuse everyone'

# %%
signals
# Out:
# {'green': 'go',
#  'yellow': 'go faster',
#  'red': 'smile for the camera',
#  'blue': 'confuse everyone'}

# %%
original_signals
# Out:
# {'green': 'go', 'yellow': 'go faster', 'red': 'smile for the camera'}

# %%
even_numbers = {0, 2, 4, 6, 8}
even_numbers
# Out:
# {0, 2, 4, 6, 8}

# %%
odd_nums = {1 ,3, 5, 7, 9}
odd_nums
# Out:
# {1, 3, 5, 7, 9}

# %%
set('letters')
# only contains unique characters
# Out:
# {'e', 'l', 'r', 's', 't'}

# %%
#make a set from a list
set(["dancer", "dasher", "prancer", "mason_dixon",])
# Out:
# {'dancer', 'dasher', 'mason_dixon', 'prancer'}

# %%
# make a set from a tuple
set(("ummagumma", "echoes", "atom heart"))
# Out:
# {'atom heart', 'echoes', 'ummagumma'}

# %%
# when you give set() a dictionary it only uses the keys
set({"apple":'red', "orange":"orange","banana":"yellow"})
# Out:
# {'apple', 'banana', 'orange'}

# %%
drinks = {
    "martini":{"vodka", "vermouth"},
    "black russian":{"vodka", "kahlua"},
    "white russian":{"cream", "kahlua", "vodka"},
    "manhattan":{"rye", "vermouth", "bitters"},
    "screwdriver":{"orange juice", "vodka"}    
}

# %%
# which drinks contain vodka?

for name, contents in drinks.items():
    if "vodka" in contents:
        print(name)
# Out:
# martini
# black russian
# white russian
# screwdriver

# %%
# now we want something with vodka but are lactose intolerant and dont like vermouth

for name, contents in drinks.items():
    if "vodka" in contents and not ("cream" in contents or "vermouth" in contents):
        print(name)
# Out:
# black russian
# screwdriver

# %%
# what if we want a drink that has either vermouth or OJ?
for name, contents in drinks.items():
    if contents & {"vermouth", "orange juice"}:
        print(name)
# Out:
# martini
# manhattan
# screwdriver

# %%
# rewrite code in two cells above in a simpler format

for name, contents in drinks.items():
    if "vodka" in contents and not contents & {"vermouth", "cream"}:
        print(name)
# Out:
# black russian
# screwdriver

# %%
bruss = drinks["black russian"]
wruss = drinks["white russian"]

# %%
a = {1,2}
b = {2,3}

# %%
a & b
# Out:
# {2}

# %%
a.intersection(b)
# Out:
# {2}

# %%
bruss & wruss
# Out:
# {'kahlua', 'vodka'}

# %%
a | b
# Out:
# {1, 2, 3}

# %%
a.union(b)
# Out:
# {1, 2, 3}

# %%
bruss | wruss
# Out:
# {'cream', 'kahlua', 'vodka'}

# %%
# the difference (members of the first set but not the second 
a - b
# Out:
# {1}

# %%
a.difference(b)
# Out:
# {1}

# %%
bruss - wruss
# Out:
# set()

# %%
wruss - bruss
# Out:
# {'cream'}

# %%
# in one set or the other, but not both-----rarely used
a ^ b
# Out:
# {1, 3}

# %%
bruss ^ wruss
# Out:
# {'cream'}

# %%
marx = ['groucho', 'chico', 'harpo']
python = ['chapman', 'cleese', 'gilliam', 'jones', "palin"]
stooges = ['moe', 'curly', 'larry']

# %%
tuple_of_lists = marx, python, stooges

# %%
tuple_of_lists
# Out:
# (['groucho', 'chico', 'harpo'],
#  ['chapman', 'cleese', 'gilliam', 'jones', 'palin'],
#  ['moe', 'curly', 'larry'])

# %%
list_of_lists = [marx, python, stooges]

# %%
list_of_lists
# Out:
# [['groucho', 'chico', 'harpo'],
#  ['chapman', 'cleese', 'gilliam', 'jones', 'palin'],
#  ['moe', 'curly', 'larry']]

# %%
dict_of_lists = {"marxes": marx, "pythons":python, "Stooges":stooges}

# %%
dict_of_lists
# Out:
# {'marxes': ['groucho', 'chico', 'harpo'],
#  'pythons': ['chapman', 'cleese', 'gilliam', 'jones', 'palin'],
#  'Stooges': ['moe', 'curly', 'larry']}

# %%
houses = {
    (44.79, -93.14, 285):"my house",
    (38.89, -77.03, 13):"The White House"
}
houses
# Out:
# {(44.79, -93.14, 285): 'my house', (38.89, -77.03, 13): 'The White House'}

# %%
random = ["mozzarella", "cinderella", "salmonella"]

# %%
random[1].capitalize()
# Out:
# 'Cinderella'

# %%
random
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
random[0] = random[0].upper()
random[1] = random[1].capitalize()

# %%
random.remove("salmonella")

# %%
random
# Out:
# ['MOZZARELLA', 'Cinderella']
